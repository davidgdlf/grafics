# %%
import pandas as pd
import matplotlib.pyplot as py

datos =pd.read_csv("products.csv")
df=datos[['unitsInStock', 'categoryID']]
df.head(25).plot.barh(x="unitsInStock", y="categoryID")
# Out:
# <AxesSubplot:ylabel='unitsInStock'>

# %%
import pandas as pd
import matplotlib.pyplot as py

df =pd.read_csv("products.csv")
df.head(10).unitPrice.plot.pie()
# Out:
# <AxesSubplot:ylabel='unitPrice'>

# %%
import pandas as pd
import matplotlib.pyplot as py

df =pd.read_csv("products.csv")
df.head(10).plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
